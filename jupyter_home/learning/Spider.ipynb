# %%
#!/usr/bin/python3
# -*- coding: utf-8 -*-
import requests
import json

# 定义请求url
url = "https://movie.douban.com/j/search_subjects"
# 定义请求头
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"
}
# 循环构建请求参数并且发送请求
movies = {}
for page_start in range(0, 100, 20):
    print('Current page: %s ...' % page_start)
    params = {
        "type": "movie",
        "tag": "豆瓣高分",
        "sort": "recommend",
        "page_limit": "20",
        "page_start": page_start
    }
    response = requests.get(
        url=url,
        headers=headers,
        params=params
    )
    # 方式一:直接转换json方法
    # results = response.json()
    # 方式二: 手动转换
    # 获取字节串
    content = response.content
    # 转换成字符串
    string = content.decode('utf-8')
    # 把字符串转成python数据类型
    results = json.loads(string)
    # 解析结果
    for movie in results["subjects"]:
        movies[movie["title"]] = movie["rate"]
new_movies = sorted(movies.items(), key=lambda m: m[1], reverse=True)
for i in new_movies:
    print(i[0], i[1])
# Out:
# Current page: 0 ...
# Current page: 20 ...
# Current page: 40 ...
# Current page: 60 ...
# Current page: 80 ...
# 肖申克的救赎 9.6
# 霸王别姬 9.6
# 美丽人生 9.5
# 辛德勒的名单 9.5
# 这个杀手不太冷 9.4
# 阿甘正传 9.4
# 泰坦尼克号 9.3
# 千与千寻 9.3
# 盗梦空间 9.3
# 忠犬八公的故事 9.3
# 放牛班的春天 9.3
# 机器人总动员 9.3
# 熔炉 9.3
# 教父 9.3
# 疯狂动物城 9.2
# 三傻大闹宝莱坞 9.2
# 星际穿越 9.2
# 楚门的世界 9.2
# 大话西游之大圣娶亲 9.2
# 龙猫 9.2
# 海上钢琴师 9.2
# 触不可及 9.2
# 素媛 9.2
# 活着 9.2
# 无间道 9.1
# 蝙蝠侠：黑暗骑士 9.1
# 末代皇帝 9.1
# 天空之城 9.1
# 我不是药神 9.0
# 摔跤吧！爸爸 9.0
# 寻梦环游记 9.0
# 怦然心动 9.0
# 当幸福来敲门 9.0
# 大话西游之月光宝盒 9.0
# 飞屋环游记 9.0
# 少年派的奇幻漂流 9.0
# 哈尔的移动城堡 9.0
# 罗马假日 9.0
# 闻香识女人 9.0
# 狮子王 9.0
# 绿皮书 8.9
# 何以为家 8.9
# V字仇杀队 8.9
# 哈利·波特与魔法石 8.9
# 情书 8.9
# 猫鼠游戏 8.9
# 黑客帝国 8.9
# 被嫌弃的松子的一生 8.9
# 看不见的客人 8.8
# 西西里的美丽传说 8.8
# 布达佩斯大饭店 8.8
# 请以你的名字呼唤我 8.8
# 本杰明·巴顿奇事 8.8
# 七宗罪 8.8
# 小偷家族 8.7
# 头号玩家 8.7
# 蜘蛛侠：平行宇宙 8.7
# 让子弹飞 8.7
# 阿凡达 8.7
# 波西米亚狂想曲 8.7
# 三块广告牌 8.7
# 喜剧之王 8.7
# 血战钢锯岭 8.7
# 剪刀手爱德华 8.7
# 天使爱美丽 8.7
# 加勒比海盗 8.7
# 蝴蝶效应 8.7
# 倩女幽魂 8.7
# 禁闭岛 8.7
# 疯狂原始人 8.7
# 消失的爱人 8.7
# 网络谜踪 8.6
# 超能陆战队 8.6
# 奇迹男孩 8.6
# 唐伯虎点秋香 8.5
# 神偷奶爸 8.5
# 你的名字。 8.4
# 釜山行 8.4
# 敦刻尔克 8.4
# 疯狂的石头 8.4
# 火星救援 8.4
# 调音师 8.3
# 红海行动 8.3
# 驴得水 8.3
# 初恋这件小事 8.3
# 功夫 8.3
# 爱乐之城 8.3
# 暴裂无声 8.3
# 钢铁侠 8.2
# 狗十三 8.2
# 天才枪手 8.2
# 复仇者联盟3：无限战争 8.1
# 复仇者联盟 8.1
# 银河护卫队 8.1
# 无双 8.1
# 无名之辈 8.1
# 碟中谍6：全面瓦解 8.1
# 那些年，我们一起追的女孩 8.1
# 无敌破坏王2：大闹互联网 8.1
# 银河护卫队2 8.0

# %%
#!/usr/bin/python3
# -*- coding: utf-8 -*-
import requests


class TiebaSpider():

    def __init__(self, kw, max_pn):
        self.max_pn = max_pn
        self.kw = kw
        self.base_url = "https://tieba.baidu.com/f?kw={}&ie=utf-8&pn={}"
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"
        }
        pass

    def get_url_list(self):
        '''
        获取 url 列表
        :return:
        '''
        # 写法一
        '''
        url_list = []
        for pn in range(0,self.max_pn,50):
            url = self.base_url.format(self.kw,pn)
            url_list.append(url)
        return url_list
        '''
        # 写法二
        return [self.base_url.format(self.kw, pn) for pn in range(0, self.max_pn, 50)]

    def get_content(self, url):
        '''
        发送请求获取响应内容
        :param url:
        :return:
        '''
        response = requests.get(
            url=url,
            headers=self.headers
        )

        return response.content

    def get_items(self, content, index):
        '''
        从响应内容中提取数据
        :param content:
        :return:
        '''
        with open('tieba-{}.html'.format(index), 'wb') as f:
            f.write(content)
        return None

    def save_items(self, items):
        '''
        保存数据
        :param items:
        :return:
        '''
        pass

    def run(self):
        # 1. 获取 url 列表
        url_list = self.get_url_list()

        for url in url_list:
            # 2. 发送请求获取响应
            content = self.get_content(url)
            # 3. 从响应中提取数据
            items = self.get_items(content, url_list.index(url) + 1)
            # 4. 保存数据
            self.save_items(items)

        pass


if __name__ == '__main__':
    spider = TiebaSpider("英雄联盟", 150)
    spider.run()
