# %%
import requests

# %%
headers = {
    'Host': 'm.douban.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json',
    'X-Requested-With': 'XMLHttpRequest',
    'User-Agent': 'Mozilla/5.0 (Linux; U; Android 7.0; zh-cn; MI NOTE Pro Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/61.0.3163.128 Mobile Safari/537.36 XiaoMi/MiuiBrowser/10.3.2',
    'Referer': 'https://m.douban.com/movie/subject/26928226/comments?from=subject',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'zh-CN,en-US;q=0.8',
#     'Cookie': 'bid=rFnS5nHo_8A; talionnav_show_app="0"; Hm_lvt_6d4a8cfea88fa457c3127e14fb5fabc2=1550988303; Hm_lpvt_6d4a8cfea88fa457c3127e14fb5fabc2=1550988350; _ga=GA1.3.1884464495.1550988306; _gid=GA1.3.1549234836.1550988306'

}

# %%
url = 'https://m.douban.com/rexxar/api/v2/tv/26928226/interests?count=50&order_by=hot&start=300&ck=&for_mobile=1'
# url = 'https://m.douban.com/movie/subject/26928226/'
result = requests.get(url, headers=headers)

# %%
result
print()
import json
json.loads(result.text)
# Out:
# <Response [200]>
# {'count': 50,
#  'start': 300,
#  'total': 50811,
#  'interests': [{'comment': '老老实实的宣传不好么？为什么要碰瓷红楼梦？？？',
#    'rating': {'count': 1, 'max': 5, 'star_count': 1, 'value': 1},
#    'sharing_url': 'https://www.douban.com/doubanapp/dispatch?uri=/movie/26928226/interest/1598609540',
#    'is_voted': False,
#    'uri': 'douban://douban.com/tv/26928226/interest/1598609540',
#    'platforms': [],
#    'vote_count': 130,
#    'create_time': '2018-12-29 09:57:19',
#    'status': 'done',
#    'user': {'loc': None,
#     'kind': 'user',
#     'followed': False,
#     'name': '豆豆',
#     'in_blacklist': False,
#     'url': 'https://www.douban.com/people/183502022/',
#     'gender': '',
#     'remark': '',
#     'uri': 'douban://douban.com/user/183502022',
#     'avatar': 'https://img3.doubanio.com/icon/up183502022-1.jpg',
#     'type': 'user',
#     'id': '183502022',
#     'uid': '183502022'},
#    'id': '1598609540'},
#   {'comment': '矫揉造作，堪比第二部娘道',
# ...
