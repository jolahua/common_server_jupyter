# %% [markdown]
# 文章来源： https://blog.csdn.net/baidu_41605403/article/details/83006973

# %% [markdown]
# 我们以Iris数据集（Iris）为例进行分析。Iris以鸢尾花的特征作为数据来源，数据集包含150个数据源，分为三类，每类50个数据集，每个数据包含4个属性，是在数据挖掘、数据分类中非常常用的测试集、训练集。决策树可以用于分类和回归，接下来我们将在代码中进行介绍。

# %% [markdown]
# 1、导入所需要的包，并创建sparkcontent和session对象

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import datetime
from pyspark.ml.linalg import Vectors, Vector
from pyspark.sql import Row
from pyspark.ml import Pipeline
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
from pyspark import SparkContext
from pyspark.sql.session import SparkSession

# 以下为决策树所需要的包
from pyspark.ml.classification import DecisionTreeClassificationModel, DecisionTreeClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# 决策树回归模型
from pyspark.ml.regression import DecisionTreeRegressionModel, DecisionTreeRegressor
from pyspark.ml.evaluation import RegressionEvaluator

# %%
try:
    sc = SparkContext('local', 'iris')
    spark = SparkSession(sc)
except:
    pass
# help(Row)
print('Initial Done at', datetime.datetime.now())
# Out:
# Initial Done at 2019-05-30 10:10:05.513040

# %%
# help(SparkContext)
# 停止sc对象
try:
    sc.stop()
    del sc
except:
    pass
print('Stop Done at', datetime.datetime.now())
# Out:
# Stop Done at 2019-05-30 11:01:29.268265

# %% [markdown]
# 2、读取数据，简要分析：
#     读取文本时，第一个map把每行的数据用【空格】隔开，比如在我们数据集中，每行被分成了5部分，前4部分是鸢尾花的4个特征，最后一个是分类；我们把特征存储在Vector中，创建一个Iris模式的RDD，之后转换成Dataframe；然后把刚刚得到的数据注册成一个表iris，之后就可以通过sql语句进行数据查询；选出我们要的数据后，我们把结果打印出来看一下结构。

# %%
def f(x):
    rel = {}
    rel['label'] = str(x[0])
    # 下面将feature按照“：” 分割字符串通过map传递总共4个给vectors
    rel['features'] = Vectors.dense(*map(lambda x: float(x.split(':')[1]), x[1:]))
    return rel

data = sc.textFile('iris.txt').map(lambda line: line.split(' ')).map(lambda p: Row(**f(p))).toDF()
data.collect()
data.createOrReplaceTempView('iris')
df = spark.sql('select * from iris')

rel = df.rdd.map(lambda t: '%s: %s' % (str(t[1]), str(t[0]))).collect()
for item in rel:
    print(item)
# Out:
# [Row(features=DenseVector([5.1, 3.5, 1.4, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.9, 3.0, 1.4, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.7, 3.2, 1.3, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.6, 3.1, 1.5, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.0, 3.6, 1.4, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.4, 3.9, 1.7, 0.4]), label='0.0'),
#  Row(features=DenseVector([4.6, 3.4, 1.4, 0.3]), label='0.0'),
#  Row(features=DenseVector([5.0, 3.4, 1.5, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.4, 2.9, 1.4, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.9, 3.1, 1.5, 0.1]), label='0.0'),
#  Row(features=DenseVector([5.4, 3.7, 1.5, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.8, 3.4, 1.6, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.8, 3.0, 1.4, 0.1]), label='0.0'),
#  Row(features=DenseVector([4.3, 3.0, 1.1, 0.1]), label='0.0'),
#  Row(features=DenseVector([5.8, 4.0, 1.2, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.7, 4.4, 1.5, 0.4]), label='0.0'),
#  Row(features=DenseVector([5.4, 3.9, 1.3, 0.4]), label='0.0'),
#  Row(features=DenseVector([5.1, 3.5, 1.4, 0.3]), label='0.0'),
#  Row(features=DenseVector([5.7, 3.8, 1.7, 0.3]), label='0.0'),
#  Row(features=DenseVector([5.1, 3.8, 1.5, 0.3]), label='0.0'),
#  Row(features=DenseVector([5.4, 3.4, 1.7, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.1, 3.7, 1.5, 0.4]), label='0.0'),
#  Row(features=DenseVector([4.6, 3.6, 1.0, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.1, 3.3, 1.7, 0.5]), label='0.0'),
#  Row(features=DenseVector([4.8, 3.4, 1.9, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.0, 3.0, 1.6, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.0, 3.4, 1.6, 0.4]), label='0.0'),
#  Row(features=DenseVector([5.2, 3.5, 1.5, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.2, 3.4, 1.4, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.7, 3.2, 1.6, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.8, 3.1, 1.6, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.4, 3.4, 1.5, 0.4]), label='0.0'),
#  Row(features=DenseVector([5.2, 4.1, 1.5, 0.1]), label='0.0'),
#  Row(features=DenseVector([5.5, 4.2, 1.4, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.9, 3.1, 1.5, 0.1]), label='0.0'),
#  Row(features=DenseVector([5.0, 3.2, 1.2, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.5, 3.5, 1.3, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.9, 3.1, 1.5, 0.1]), label='0.0'),
#  Row(features=DenseVector([4.4, 3.0, 1.3, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.1, 3.4, 1.5, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.0, 3.5, 1.3, 0.3]), label='0.0'),
#  Row(features=DenseVector([4.5, 2.3, 1.3, 0.3]), label='0.0'),
#  Row(features=DenseVector([4.4, 3.2, 1.3, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.0, 3.5, 1.6, 0.6]), label='0.0'),
#  Row(features=DenseVector([5.1, 3.8, 1.9, 0.4]), label='0.0'),
#  Row(features=DenseVector([4.8, 3.0, 1.4, 0.3]), label='0.0'),
#  Row(features=DenseVector([5.1, 3.8, 1.6, 0.2]), label='0.0'),
#  Row(features=DenseVector([4.6, 3.2, 1.4, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.3, 3.7, 1.5, 0.2]), label='0.0'),
#  Row(features=DenseVector([5.0, 3.3, 1.4, 0.2]), label='0.0'),
#  Row(features=DenseVector([7.0, 3.2, 4.7, 1.4]), label='1.0'),
#  Row(features=DenseVector([6.4, 3.2, 4.5, 1.5]), label='1.0'),
#  Row(features=DenseVector([6.9, 3.1, 4.9, 1.5]), label='1.0'),
#  Row(features=DenseVector([5.5, 2.3, 4.0, 1.3]), label='1.0'),
#  Row(features=DenseVector([6.5, 2.8, 4.6, 1.5]), label='1.0'),
#  Row(features=DenseVector([5.7, 2.8, 4.5, 1.3]), label='1.0'),
#  Row(features=DenseVector([6.3, 3.3, 4.7, 1.6]), label='1.0'),
#  Row(features=DenseVector([4.9, 2.4, 3.3, 1.0]), label='1.0'),
#  Row(features=DenseVector([6.6, 2.9, 4.6, 1.3]), label='1.0'),
#  Row(features=DenseVector([5.2, 2.7, 3.9, 1.4]), label='1.0'),
#  Row(features=DenseVector([5.0, 2.0, 3.5, 1.0]), label='1.0'),
#  Row(features=DenseVector([5.9, 3.0, 4.2, 1.5]), label='1.0'),
#  Row(features=DenseVector([6.0, 2.2, 4.0, 1.0]), label='1.0'),
#  Row(features=DenseVector([6.1, 2.9, 4.7, 1.4]), label='1.0'),
#  Row(features=DenseVector([5.6, 2.9, 3.6, 1.3]), label='1.0'),
#  Row(features=DenseVector([6.7, 3.1, 4.4, 1.4]), label='1.0'),
#  Row(features=DenseVector([5.6, 3.0, 4.5, 1.5]), label='1.0'),
#  Row(features=DenseVector([5.8, 2.7, 4.1, 1.0]), label='1.0'),
#  Row(features=DenseVector([6.2, 2.2, 4.5, 1.5]), label='1.0'),
#  Row(features=DenseVector([5.6, 2.5, 3.9, 1.1]), label='1.0'),
#  Row(features=DenseVector([5.9, 3.2, 4.8, 1.8]), label='1.0'),
#  Row(features=DenseVector([6.1, 2.8, 4.0, 1.3]), label='1.0'),
#  Row(features=DenseVector([6.3, 2.5, 4.9, 1.5]), label='1.0'),
#  Row(features=DenseVector([6.1, 2.8, 4.7, 1.2]), label='1.0'),
#  Row(features=DenseVector([6.4, 2.9, 4.3, 1.3]), label='1.0'),
#  Row(features=DenseVector([6.6, 3.0, 4.4, 1.4]), label='1.0'),
#  Row(features=DenseVector([6.8, 2.8, 4.8, 1.4]), label='1.0'),
#  Row(features=DenseVector([6.7, 3.0, 5.0, 1.7]), label='1.0'),
#  Row(features=DenseVector([6.0, 2.9, 4.5, 1.5]), label='1.0'),
#  Row(features=DenseVector([5.7, 2.6, 3.5, 1.0]), label='1.0'),
#  Row(features=DenseVector([5.5, 2.4, 3.8, 1.1]), label='1.0'),
#  Row(features=DenseVector([5.5, 2.4, 3.7, 1.0]), label='1.0'),
#  Row(features=DenseVector([5.8, 2.7, 3.9, 1.2]), label='1.0'),
#  Row(features=DenseVector([6.0, 2.7, 5.1, 1.6]), label='1.0'),
#  Row(features=DenseVector([5.4, 3.0, 4.5, 1.5]), label='1.0'),
#  Row(features=DenseVector([6.0, 3.4, 4.5, 1.6]), label='1.0'),
#  Row(features=DenseVector([6.7, 3.1, 4.7, 1.5]), label='1.0'),
#  Row(features=DenseVector([6.3, 2.3, 4.4, 1.3]), label='1.0'),
#  Row(features=DenseVector([5.6, 3.0, 4.1, 1.3]), label='1.0'),
#  Row(features=DenseVector([5.5, 2.5, 4.0, 1.3]), label='1.0'),
#  Row(features=DenseVector([5.5, 2.6, 4.4, 1.2]), label='1.0'),
#  Row(features=DenseVector([6.1, 3.0, 4.6, 1.4]), label='1.0'),
#  Row(features=DenseVector([5.8, 2.6, 4.0, 1.2]), label='1.0'),
#  Row(features=DenseVector([5.0, 2.3, 3.3, 1.0]), label='1.0'),
#  Row(features=DenseVector([5.6, 2.7, 4.2, 1.3]), label='1.0'),
#  Row(features=DenseVector([5.7, 3.0, 4.2, 1.2]), label='1.0'),
#  Row(features=DenseVector([5.7, 2.9, 4.2, 1.3]), label='1.0'),
#  Row(features=DenseVector([6.2, 2.9, 4.3, 1.3]), label='1.0'),
#  Row(features=DenseVector([5.1, 2.5, 3.0, 1.1]), label='1.0'),
#  Row(features=DenseVector([5.7, 2.8, 4.1, 1.3]), label='1.0'),
#  Row(features=DenseVector([6.3, 3.3, 6.0, 2.5]), label='2.0'),
#  Row(features=DenseVector([5.8, 2.7, 5.1, 1.9]), label='2.0'),
#  Row(features=DenseVector([7.1, 3.0, 5.9, 2.1]), label='2.0'),
#  Row(features=DenseVector([6.3, 2.9, 5.6, 1.8]), label='2.0'),
#  Row(features=DenseVector([6.5, 3.0, 5.8, 2.2]), label='2.0'),
#  Row(features=DenseVector([7.6, 3.0, 6.6, 2.1]), label='2.0'),
#  Row(features=DenseVector([4.9, 2.5, 4.5, 1.7]), label='2.0'),
#  Row(features=DenseVector([7.3, 2.9, 6.3, 1.8]), label='2.0'),
#  Row(features=DenseVector([6.7, 2.5, 5.8, 1.8]), label='2.0'),
#  Row(features=DenseVector([7.2, 3.6, 6.1, 2.5]), label='2.0'),
#  Row(features=DenseVector([6.5, 3.2, 5.1, 2.0]), label='2.0'),
#  Row(features=DenseVector([6.4, 2.7, 5.3, 1.9]), label='2.0'),
#  Row(features=DenseVector([6.8, 3.0, 5.5, 2.1]), label='2.0'),
#  Row(features=DenseVector([5.7, 2.5, 5.0, 2.0]), label='2.0'),
#  Row(features=DenseVector([5.8, 2.8, 5.1, 2.4]), label='2.0'),
#  Row(features=DenseVector([6.4, 3.2, 5.3, 2.3]), label='2.0'),
#  Row(features=DenseVector([6.5, 3.0, 5.5, 1.8]), label='2.0'),
#  Row(features=DenseVector([7.7, 3.8, 6.7, 2.2]), label='2.0'),
#  Row(features=DenseVector([7.7, 2.6, 6.9, 2.3]), label='2.0'),
#  Row(features=DenseVector([6.0, 2.2, 5.0, 1.5]), label='2.0'),
#  Row(features=DenseVector([6.9, 3.2, 5.7, 2.3]), label='2.0'),
#  Row(features=DenseVector([5.6, 2.8, 4.9, 2.0]), label='2.0'),
#  Row(features=DenseVector([7.7, 2.8, 6.7, 2.0]), label='2.0'),
#  Row(features=DenseVector([6.3, 2.7, 4.9, 1.8]), label='2.0'),
#  Row(features=DenseVector([6.7, 3.3, 5.7, 2.1]), label='2.0'),
#  Row(features=DenseVector([7.2, 3.2, 6.0, 1.8]), label='2.0'),
#  Row(features=DenseVector([6.2, 2.8, 4.8, 1.8]), label='2.0'),
#  Row(features=DenseVector([6.1, 3.0, 4.9, 1.8]), label='2.0'),
#  Row(features=DenseVector([6.4, 2.8, 5.6, 2.1]), label='2.0'),
#  Row(features=DenseVector([7.2, 3.0, 5.8, 1.6]), label='2.0'),
#  Row(features=DenseVector([7.4, 2.8, 6.1, 1.9]), label='2.0'),
#  Row(features=DenseVector([7.9, 3.8, 6.4, 2.0]), label='2.0'),
#  Row(features=DenseVector([6.4, 2.8, 5.6, 2.2]), label='2.0'),
#  Row(features=DenseVector([6.3, 2.8, 5.1, 1.5]), label='2.0'),
#  Row(features=DenseVector([6.1, 2.6, 5.6, 1.4]), label='2.0'),
#  Row(features=DenseVector([7.7, 3.0, 6.1, 2.3]), label='2.0'),
#  Row(features=DenseVector([6.3, 3.4, 5.6, 2.4]), label='2.0'),
#  Row(features=DenseVector([6.4, 3.1, 5.5, 1.8]), label='2.0'),
#  Row(features=DenseVector([6.0, 3.0, 4.8, 1.8]), label='2.0'),
#  Row(features=DenseVector([6.9, 3.1, 5.4, 2.1]), label='2.0'),
#  Row(features=DenseVector([6.7, 3.1, 5.6, 2.4]), label='2.0'),
#  Row(features=DenseVector([6.9, 3.1, 5.1, 2.3]), label='2.0'),
#  Row(features=DenseVector([5.8, 2.7, 5.1, 1.9]), label='2.0'),
#  Row(features=DenseVector([6.8, 3.2, 5.9, 2.3]), label='2.0'),
#  Row(features=DenseVector([6.7, 3.3, 5.7, 2.5]), label='2.0'),
#  Row(features=DenseVector([6.7, 3.0, 5.2, 2.3]), label='2.0'),
#  Row(features=DenseVector([6.3, 2.5, 5.0, 1.9]), label='2.0'),
#  Row(features=DenseVector([6.5, 3.0, 5.2, 2.0]), label='2.0'),
#  Row(features=DenseVector([6.2, 3.4, 5.4, 2.3]), label='2.0'),
#  Row(features=DenseVector([5.9, 3.0, 5.1, 1.8]), label='2.0')]
# 0.0: [5.1,3.5,1.4,0.2]
# 0.0: [4.9,3.0,1.4,0.2]
# 0.0: [4.7,3.2,1.3,0.2]
# 0.0: [4.6,3.1,1.5,0.2]
# 0.0: [5.0,3.6,1.4,0.2]
# 0.0: [5.4,3.9,1.7,0.4]
# 0.0: [4.6,3.4,1.4,0.3]
# 0.0: [5.0,3.4,1.5,0.2]
# 0.0: [4.4,2.9,1.4,0.2]
# 0.0: [4.9,3.1,1.5,0.1]
# 0.0: [5.4,3.7,1.5,0.2]
# 0.0: [4.8,3.4,1.6,0.2]
# 0.0: [4.8,3.0,1.4,0.1]
# 0.0: [4.3,3.0,1.1,0.1]
# 0.0: [5.8,4.0,1.2,0.2]
# 0.0: [5.7,4.4,1.5,0.4]
# 0.0: [5.4,3.9,1.3,0.4]
# 0.0: [5.1,3.5,1.4,0.3]
# 0.0: [5.7,3.8,1.7,0.3]
# 0.0: [5.1,3.8,1.5,0.3]
# 0.0: [5.4,3.4,1.7,0.2]
# 0.0: [5.1,3.7,1.5,0.4]
# 0.0: [4.6,3.6,1.0,0.2]
# 0.0: [5.1,3.3,1.7,0.5]
# 0.0: [4.8,3.4,1.9,0.2]
# 0.0: [5.0,3.0,1.6,0.2]
# 0.0: [5.0,3.4,1.6,0.4]
# 0.0: [5.2,3.5,1.5,0.2]
# 0.0: [5.2,3.4,1.4,0.2]
# 0.0: [4.7,3.2,1.6,0.2]
# 0.0: [4.8,3.1,1.6,0.2]
# 0.0: [5.4,3.4,1.5,0.4]
# 0.0: [5.2,4.1,1.5,0.1]
# 0.0: [5.5,4.2,1.4,0.2]
# 0.0: [4.9,3.1,1.5,0.1]
# 0.0: [5.0,3.2,1.2,0.2]
# 0.0: [5.5,3.5,1.3,0.2]
# 0.0: [4.9,3.1,1.5,0.1]
# 0.0: [4.4,3.0,1.3,0.2]
# 0.0: [5.1,3.4,1.5,0.2]
# 0.0: [5.0,3.5,1.3,0.3]
# 0.0: [4.5,2.3,1.3,0.3]
# 0.0: [4.4,3.2,1.3,0.2]
# 0.0: [5.0,3.5,1.6,0.6]
# 0.0: [5.1,3.8,1.9,0.4]
# 0.0: [4.8,3.0,1.4,0.3]
# 0.0: [5.1,3.8,1.6,0.2]
# 0.0: [4.6,3.2,1.4,0.2]
# 0.0: [5.3,3.7,1.5,0.2]
# 0.0: [5.0,3.3,1.4,0.2]
# 1.0: [7.0,3.2,4.7,1.4]
# 1.0: [6.4,3.2,4.5,1.5]
# 1.0: [6.9,3.1,4.9,1.5]
# 1.0: [5.5,2.3,4.0,1.3]
# 1.0: [6.5,2.8,4.6,1.5]
# 1.0: [5.7,2.8,4.5,1.3]
# 1.0: [6.3,3.3,4.7,1.6]
# 1.0: [4.9,2.4,3.3,1.0]
# 1.0: [6.6,2.9,4.6,1.3]
# 1.0: [5.2,2.7,3.9,1.4]
# 1.0: [5.0,2.0,3.5,1.0]
# 1.0: [5.9,3.0,4.2,1.5]
# 1.0: [6.0,2.2,4.0,1.0]
# 1.0: [6.1,2.9,4.7,1.4]
# 1.0: [5.6,2.9,3.6,1.3]
# 1.0: [6.7,3.1,4.4,1.4]
# 1.0: [5.6,3.0,4.5,1.5]
# 1.0: [5.8,2.7,4.1,1.0]
# 1.0: [6.2,2.2,4.5,1.5]
# 1.0: [5.6,2.5,3.9,1.1]
# 1.0: [5.9,3.2,4.8,1.8]
# 1.0: [6.1,2.8,4.0,1.3]
# 1.0: [6.3,2.5,4.9,1.5]
# 1.0: [6.1,2.8,4.7,1.2]
# 1.0: [6.4,2.9,4.3,1.3]
# 1.0: [6.6,3.0,4.4,1.4]
# 1.0: [6.8,2.8,4.8,1.4]
# 1.0: [6.7,3.0,5.0,1.7]
# 1.0: [6.0,2.9,4.5,1.5]
# 1.0: [5.7,2.6,3.5,1.0]
# 1.0: [5.5,2.4,3.8,1.1]
# 1.0: [5.5,2.4,3.7,1.0]
# 1.0: [5.8,2.7,3.9,1.2]
# 1.0: [6.0,2.7,5.1,1.6]
# 1.0: [5.4,3.0,4.5,1.5]
# 1.0: [6.0,3.4,4.5,1.6]
# 1.0: [6.7,3.1,4.7,1.5]
# 1.0: [6.3,2.3,4.4,1.3]
# 1.0: [5.6,3.0,4.1,1.3]
# 1.0: [5.5,2.5,4.0,1.3]
# 1.0: [5.5,2.6,4.4,1.2]
# 1.0: [6.1,3.0,4.6,1.4]
# 1.0: [5.8,2.6,4.0,1.2]
# 1.0: [5.0,2.3,3.3,1.0]
# 1.0: [5.6,2.7,4.2,1.3]
# 1.0: [5.7,3.0,4.2,1.2]
# 1.0: [5.7,2.9,4.2,1.3]
# 1.0: [6.2,2.9,4.3,1.3]
# 1.0: [5.1,2.5,3.0,1.1]
# 1.0: [5.7,2.8,4.1,1.3]
# 2.0: [6.3,3.3,6.0,2.5]
# 2.0: [5.8,2.7,5.1,1.9]
# 2.0: [7.1,3.0,5.9,2.1]
# 2.0: [6.3,2.9,5.6,1.8]
# 2.0: [6.5,3.0,5.8,2.2]
# 2.0: [7.6,3.0,6.6,2.1]
# 2.0: [4.9,2.5,4.5,1.7]
# 2.0: [7.3,2.9,6.3,1.8]
# 2.0: [6.7,2.5,5.8,1.8]
# 2.0: [7.2,3.6,6.1,2.5]
# 2.0: [6.5,3.2,5.1,2.0]
# 2.0: [6.4,2.7,5.3,1.9]
# 2.0: [6.8,3.0,5.5,2.1]
# 2.0: [5.7,2.5,5.0,2.0]
# 2.0: [5.8,2.8,5.1,2.4]
# 2.0: [6.4,3.2,5.3,2.3]
# 2.0: [6.5,3.0,5.5,1.8]
# 2.0: [7.7,3.8,6.7,2.2]
# 2.0: [7.7,2.6,6.9,2.3]
# 2.0: [6.0,2.2,5.0,1.5]
# 2.0: [6.9,3.2,5.7,2.3]
# 2.0: [5.6,2.8,4.9,2.0]
# 2.0: [7.7,2.8,6.7,2.0]
# 2.0: [6.3,2.7,4.9,1.8]
# 2.0: [6.7,3.3,5.7,2.1]
# 2.0: [7.2,3.2,6.0,1.8]
# 2.0: [6.2,2.8,4.8,1.8]
# 2.0: [6.1,3.0,4.9,1.8]
# 2.0: [6.4,2.8,5.6,2.1]
# 2.0: [7.2,3.0,5.8,1.6]
# 2.0: [7.4,2.8,6.1,1.9]
# 2.0: [7.9,3.8,6.4,2.0]
# 2.0: [6.4,2.8,5.6,2.2]
# 2.0: [6.3,2.8,5.1,1.5]
# 2.0: [6.1,2.6,5.6,1.4]
# 2.0: [7.7,3.0,6.1,2.3]
# 2.0: [6.3,3.4,5.6,2.4]
# 2.0: [6.4,3.1,5.5,1.8]
# 2.0: [6.0,3.0,4.8,1.8]
# 2.0: [6.9,3.1,5.4,2.1]
# 2.0: [6.7,3.1,5.6,2.4]
# 2.0: [6.9,3.1,5.1,2.3]
# 2.0: [5.8,2.7,5.1,1.9]
# 2.0: [6.8,3.2,5.9,2.3]
# 2.0: [6.7,3.3,5.7,2.5]
# 2.0: [6.7,3.0,5.2,2.3]
# 2.0: [6.3,2.5,5.0,1.9]
# 2.0: [6.5,3.0,5.2,2.0]
# 2.0: [6.2,3.4,5.4,2.3]
# 2.0: [5.9,3.0,5.1,1.8]

# %% [markdown]
# 3、进一步处理特征和标签，以及数据分组：

# %%
# 分别获取标签列和特征列，进行索引，并进行了重命名
label_indexer = StringIndexer(inputCol='label', outputCol='indexedLabel')
label_indexer.fit(df)

feature_indexer = VectorIndexer(inputCol='features', outputCol='indexedFeatures', maxCategories=4)
feature_indexer.fit(df)

# 设置一个labelConverter，目的是把预测的类别重新转换成字符型的
labelConverter = IndexToString(inputCol='prediction', outputCol='predictedLabel', labels=label_indexer.labels)
# 数据集切分
training_data, test_data = data.randomSplit([0.7, 0.3])
# Out:
# label_indexer:  StringIndexer_8412c0946407

# %%
type(label_indexer)
type(df)
d = df.toPandas()
d
# Out:
# pyspark.ml.feature.StringIndexerModel
# pyspark.sql.dataframe.DataFrame
#                  features label
# 0    [5.1, 3.5, 1.4, 0.2]   0.0
# 1    [4.9, 3.0, 1.4, 0.2]   0.0
# 2    [4.7, 3.2, 1.3, 0.2]   0.0
# 3    [4.6, 3.1, 1.5, 0.2]   0.0
# 4    [5.0, 3.6, 1.4, 0.2]   0.0
# 5    [5.4, 3.9, 1.7, 0.4]   0.0
# 6    [4.6, 3.4, 1.4, 0.3]   0.0
# 7    [5.0, 3.4, 1.5, 0.2]   0.0
# 8    [4.4, 2.9, 1.4, 0.2]   0.0
# 9    [4.9, 3.1, 1.5, 0.1]   0.0
# 10   [5.4, 3.7, 1.5, 0.2]   0.0
# 11   [4.8, 3.4, 1.6, 0.2]   0.0
# 12   [4.8, 3.0, 1.4, 0.1]   0.0
# 13   [4.3, 3.0, 1.1, 0.1]   0.0
# 14   [5.8, 4.0, 1.2, 0.2]   0.0
# 15   [5.7, 4.4, 1.5, 0.4]   0.0
# 16   [5.4, 3.9, 1.3, 0.4]   0.0
# 17   [5.1, 3.5, 1.4, 0.3]   0.0
# 18   [5.7, 3.8, 1.7, 0.3]   0.0
# 19   [5.1, 3.8, 1.5, 0.3]   0.0
# 20   [5.4, 3.4, 1.7, 0.2]   0.0
# 21   [5.1, 3.7, 1.5, 0.4]   0.0
# 22   [4.6, 3.6, 1.0, 0.2]   0.0
# 23   [5.1, 3.3, 1.7, 0.5]   0.0
# 24   [4.8, 3.4, 1.9, 0.2]   0.0
# 25   [5.0, 3.0, 1.6, 0.2]   0.0
# 26   [5.0, 3.4, 1.6, 0.4]   0.0
# 27   [5.2, 3.5, 1.5, 0.2]   0.0
# 28   [5.2, 3.4, 1.4, 0.2]   0.0
# 29   [4.7, 3.2, 1.6, 0.2]   0.0
# ..                    ...   ...
# 120  [6.9, 3.2, 5.7, 2.3]   2.0
# 121  [5.6, 2.8, 4.9, 2.0]   2.0
# 122  [7.7, 2.8, 6.7, 2.0]   2.0
# 123  [6.3, 2.7, 4.9, 1.8]   2.0
# 124  [6.7, 3.3, 5.7, 2.1]   2.0
# 125  [7.2, 3.2, 6.0, 1.8]   2.0
# 126  [6.2, 2.8, 4.8, 1.8]   2.0
# 127  [6.1, 3.0, 4.9, 1.8]   2.0
# 128  [6.4, 2.8, 5.6, 2.1]   2.0
# 129  [7.2, 3.0, 5.8, 1.6]   2.0
# 130  [7.4, 2.8, 6.1, 1.9]   2.0
# 131  [7.9, 3.8, 6.4, 2.0]   2.0
# 132  [6.4, 2.8, 5.6, 2.2]   2.0
# 133  [6.3, 2.8, 5.1, 1.5]   2.0
# 134  [6.1, 2.6, 5.6, 1.4]   2.0
# 135  [7.7, 3.0, 6.1, 2.3]   2.0
# 136  [6.3, 3.4, 5.6, 2.4]   2.0
# 137  [6.4, 3.1, 5.5, 1.8]   2.0
# 138  [6.0, 3.0, 4.8, 1.8]   2.0
# 139  [6.9, 3.1, 5.4, 2.1]   2.0
# 140  [6.7, 3.1, 5.6, 2.4]   2.0
# 141  [6.9, 3.1, 5.1, 2.3]   2.0
# 142  [5.8, 2.7, 5.1, 1.9]   2.0
# 143  [6.8, 3.2, 5.9, 2.3]   2.0
# 144  [6.7, 3.3, 5.7, 2.5]   2.0
# 145  [6.7, 3.0, 5.2, 2.3]   2.0
# 146  [6.3, 2.5, 5.0, 1.9]   2.0
# 147  [6.5, 3.0, 5.2, 2.0]   2.0
# 148  [6.2, 3.4, 5.4, 2.3]   2.0
# 149  [5.9, 3.0, 5.1, 1.8]   2.0
#
# [150 rows x 2 columns]

# %% [markdown]
# 4、构建决策树分类模型：

# %%
dtclassifier = DecisionTreeClassifier(labelCol='indexedLabel', featuresCol='indexedFeatures')
# 在pipeline中进行设置
pipelinedClassifier = Pipeline(stages=[label_indexer, feature_indexer, dtclassifier, labelConverter])
# 训练决策树模型
modelClassifier = pipelinedClassifier.fit(training_data)
# 进行预测
predictionsClassifier = modelClassifier.transform(testData)
# 查看部分预测结果
# predictionsClassifier.select('predictedLabel', 'label', 'features').show(20)

# %%
# 查看部分预测结果
predictionsClassifier.select('predictedLabel', 'label', 'features').show(20)
# Out:
# +--------------+-----+-----------------+
# |predictedLabel|label|         features|
# +--------------+-----+-----------------+
# |           0.0|  0.0|[4.4,2.9,1.4,0.2]|
# |           0.0|  0.0|[4.4,3.2,1.3,0.2]|
# |           0.0|  0.0|[4.6,3.4,1.4,0.3]|
# |           0.0|  0.0|[4.6,3.6,1.0,0.2]|
# |           0.0|  0.0|[4.8,3.4,1.6,0.2]|
# |           1.0|  1.0|[4.9,2.4,3.3,1.0]|
# |           0.0|  0.0|[4.9,3.0,1.4,0.2]|
# |           0.0|  0.0|[5.0,3.3,1.4,0.2]|
# |           0.0|  0.0|[5.0,3.6,1.4,0.2]|
# |           1.0|  1.0|[5.2,2.7,3.9,1.4]|
# |           0.0|  0.0|[5.2,3.5,1.5,0.2]|
# |           0.0|  0.0|[5.3,3.7,1.5,0.2]|
# |           0.0|  0.0|[5.4,3.9,1.3,0.4]|
# |           0.0|  0.0|[5.5,3.5,1.3,0.2]|
# |           1.0|  1.0|[5.6,2.5,3.9,1.1]|
# |           2.0|  2.0|[5.6,2.8,4.9,2.0]|
# |           1.0|  1.0|[5.6,3.0,4.1,1.3]|
# |           1.0|  1.0|[5.6,3.0,4.5,1.5]|
# |           1.0|  1.0|[5.7,2.8,4.1,1.3]|
# |           1.0|  1.0|[5.8,2.7,3.9,1.2]|
# +--------------+-----+-----------------+
# only showing top 20 rows

# %% [markdown]
# 5、评估决策树分类模型：

# %%
evaluatorClassifier = MulticlassClassificationEvaluator(labelCol='indexedLabel', predictionCol='prediction', metricName='accuracy')
accuracy = evaluatorClassifier.evaluate(predictionsClassifier)

print('Test Error = ' + str(1.0 - accuracy))
print('Accuracy = ' + str(accuracy)
treeModelClassifier = modelClassifier.stages[2]
print("Learned classification tree model:\n" + str(treeModelClassifier.toDebugString))
# Out:
# Test Error = 0.021739130434782594
# Learned classification tree model:
# DecisionTreeClassificationModel (uid=DecisionTreeClassifier_fec9419e0228) of depth 5 with 15 nodes
#   If (feature 2 <= 2.45)
#    Predict: 1.0
#   Else (feature 2 > 2.45)
#    If (feature 3 <= 1.65)
#     If (feature 2 <= 4.95)
#      Predict: 0.0
#     Else (feature 2 > 4.95)
#      Predict: 2.0
#    Else (feature 3 > 1.65)
#     If (feature 3 <= 1.75)
#      If (feature 0 <= 4.95)
#       Predict: 2.0
#      Else (feature 0 > 4.95)
#       Predict: 0.0
#     Else (feature 3 > 1.75)
#      If (feature 2 <= 4.85)
#       If (feature 0 <= 5.95)
#        Predict: 0.0
#       Else (feature 0 > 5.95)
#        Predict: 2.0
#      Else (feature 2 > 4.85)
#       Predict: 2.0

# %% [markdown]
# 6、构建决策树回归模型

# %%
# 训练决策树回归模型
dtRegressor = DecisionTreeRegressor(labelCol='indexedLabel', featuresCol='indexedFeatures')
# 在pipeline中进行设置
pipelineRegressor = Pipeline(stages=[label_indexer, feature_indexer, dtRegressor, labelConverter])
# 训练决策树模型
modelRegressor = pipelineRegressor.fit(training_data)
# 进行预测
predictionsRegressor = modelRegressor.transform(test_data)
# 查看部分预测结果
predictionsRegressor.select('predictedLabel', 'label', 'features').show(20)
# Out:
# +--------------+-----+-----------------+
# |predictedLabel|label|         features|
# +--------------+-----+-----------------+
# |           0.0|  0.0|[4.4,2.9,1.4,0.2]|
# |           0.0|  0.0|[4.4,3.2,1.3,0.2]|
# |           0.0|  0.0|[4.6,3.4,1.4,0.3]|
# |           0.0|  0.0|[4.6,3.6,1.0,0.2]|
# |           0.0|  0.0|[4.8,3.4,1.6,0.2]|
# |           2.0|  1.0|[4.9,2.4,3.3,1.0]|
# |           0.0|  0.0|[4.9,3.0,1.4,0.2]|
# |           0.0|  0.0|[5.0,3.3,1.4,0.2]|
# |           0.0|  0.0|[5.0,3.6,1.4,0.2]|
# |           1.0|  1.0|[5.2,2.7,3.9,1.4]|
# |           0.0|  0.0|[5.2,3.5,1.5,0.2]|
# |           0.0|  0.0|[5.3,3.7,1.5,0.2]|
# |           0.0|  0.0|[5.4,3.9,1.3,0.4]|
# |           0.0|  0.0|[5.5,3.5,1.3,0.2]|
# |           1.0|  1.0|[5.6,2.5,3.9,1.1]|
# |           2.0|  2.0|[5.6,2.8,4.9,2.0]|
# |           1.0|  1.0|[5.6,3.0,4.1,1.3]|
# |           1.0|  1.0|[5.6,3.0,4.5,1.5]|
# |           1.0|  1.0|[5.7,2.8,4.1,1.3]|
# |           1.0|  1.0|[5.8,2.7,3.9,1.2]|
# +--------------+-----+-----------------+
# only showing top 20 rows

# %% [markdown]
# 7、评估决策树回归模型：

# %%
evaluatorRegressor = RegressionEvaluator(labelCol='indexedLabel', predictionCol='prediction', metricName='rmse')
rmse = evaluatorRegressor.evaluate(predictionsRegressor)

print("Root Mean Squared Error (RMSE) on test data = " +str(rmse))

treeModelRegressor = modelRegressor.stages[2]
print("Learned regression tree model:\n" + str(treeModelRegressor.toDebugString))
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.5107539184552491
# Learned regression tree model:
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_8a30f6f11ec9) of depth 4 with 13 nodes
#   If (feature 3 <= 1.75)
#    If (feature 2 <= 2.45)
#     Predict: 1.0
#    Else (feature 2 > 2.45)
#     If (feature 0 <= 4.95)
#      Predict: 2.0
#     Else (feature 0 > 4.95)
#      If (feature 2 <= 5.05)
#       Predict: 0.0
#      Else (feature 2 > 5.05)
#       Predict: 2.0
#   Else (feature 3 > 1.75)
#    If (feature 2 <= 4.85)
#     If (feature 0 <= 5.95)
#      Predict: 0.0
#     Else (feature 0 > 5.95)
#      Predict: 2.0
#    Else (feature 2 > 4.85)
#     Predict: 2.0

# %%
predictionsRegressor.show(5)
# Out:
# +-----------------+-----+------------+-----------------+----------+--------------+
# |         features|label|indexedLabel|  indexedFeatures|prediction|predictedLabel|
# +-----------------+-----+------------+-----------------+----------+--------------+
# |[4.4,2.9,1.4,0.2]|  0.0|         1.0|[4.4,2.9,1.4,0.2]|       1.0|           0.0|
# |[4.4,3.2,1.3,0.2]|  0.0|         1.0|[4.4,3.2,1.3,0.2]|       1.0|           0.0|
# |[4.6,3.4,1.4,0.3]|  0.0|         1.0|[4.6,3.4,1.4,0.3]|       1.0|           0.0|
# |[4.6,3.6,1.0,0.2]|  0.0|         1.0|[4.6,3.6,1.0,0.2]|       1.0|           0.0|
# |[4.8,3.4,1.6,0.2]|  0.0|         1.0|[4.8,3.4,1.6,0.2]|       1.0|           0.0|
# +-----------------+-----+------------+-----------------+----------+--------------+
# only showing top 5 rows

# %%
import warnings
warnings.filterwarnings('ignore')
try:
    del iris
except:
    pass
iris = data.toPandas()
i2 = iris['features'].apply(lambda l: str(l)).str.lstrip('[').str.rstrip(']').str.split(',', expand=True)
iris = iris.drop('features', axis=1).join(i2)
iris.columns=['label', '0', '1', '2', '3']
iris = iris.T.apply(pd.to_numeric).T

# %%
iris.head()
# Out:
#    label    0    1    2    3
# 0    0.0  5.1  3.5  1.4  0.2
# 1    0.0  4.9  3.0  1.4  0.2
# 2    0.0  4.7  3.2  1.3  0.2
# 3    0.0  4.6  3.1  1.5  0.2
# 4    0.0  5.0  3.6  1.4  0.2

# %%
iris['label'].value_counts()
# Out:
# 2.0    50
# 1.0    50
# 0.0    50
# Name: label, dtype: int64

# %%
iris.plot(kind='scatter', x='0', y='1')

# %%
sns.jointplot(x='0', y='1', data=iris, size=7)

# %%
sns.FacetGrid(iris, hue='label', size=5).map(plt.scatter, '0', '1').add_legend()

# %%
sns.boxplot(x='label', y='0', data=iris)

# %%
ax = sns.boxplot(data=iris, x='label', y='0')
ax = sns.stripplot(x='label', y='0', data=iris, jitter=True, edgecolor='gray')

# %%
sns.violinplot(x='label', y='2', data=iris)

# %%
sns.FacetGrid(iris, hue='label', size=6).map(sns.kdeplot, '2').add_legend()

# %%
sns.pairplot(iris, hue='label', size=4)

# %%
sns.pairplot(iris, hue='label', size=3, diag_kind='kde')

# %%
iris.boxplot(by='label', figsize=(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b75027240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b74f88390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b7456b748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b74510e10>]],
#       dtype=object)

# %%
from pandas.tools.plotting import andrews_curves
andrews_curves(iris, 'label')

# %%
from pandas.tools.plotting import parallel_coordinates
parallel_coordinates(iris, 'label')

# %%
from pandas.tools.plotting import radviz
radviz(iris, 'label')

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(iris)
# Out:
# Help on function wrapper in module pandas.tools.plotting:
#
# wrapper(*args, **kwargs)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72694ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b7253cba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b724dc400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b724fde80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b724aa940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b724aa978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72481e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72430940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b723df400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72386e80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b723b4940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72363400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72309e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72338940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b722e73c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b7228ce48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b722bc908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b7226d3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72212e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b7223f908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b721ef3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72198e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b721c3908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b721743c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b72119e48>]],
#       dtype=object)
